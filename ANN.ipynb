# %% [markdown]
# <a href="https://colab.research.google.com/github/my-thought-experiments/explore-tensorflow/blob/develop/ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.0.1

# %%
import tensorflow as tf
import numpy as np
import datetime

from tensorflow.keras.datasets import fashion_mnist

tf.__version__
# Out:
# '2.0.1'

# %% [markdown]
# ## Data Processing
#
# ### Loading the datesets

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %% [markdown]
# ### Normalizing the images

# %%
X_train = X_train / 255.0
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_test = X_test / 255.0
X_test.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# ### Reshaping the dataset

# %%
X_train = X_train.reshape(-1, 28*28)
X_train.shape
# Out:
# (60000, 784)

# %%
X_test = X_test.reshape(-1, 28*28)
X_test.shape
# Out:
# (10000, 784)

# %% [markdown]
# ## Building ANN
#
# ### Defining the model

# %%
model = tf.keras.models.Sequential()

# %% [markdown]
# ### Adding a first fully-connected hidden layer

# %%
model.add(tf.keras.layers.Dense(units=128, activation='relu', input_shape=(784,)))

# %% [markdown]
# ### Adding a second layer with Dropout

# %%
model.add(tf.keras.layers.Dropout(0.2))

# %% [markdown]
# ### Adding the output layer
#
# *   Units: number of classes (10 in the Fashion MNIST dataset)

# %%
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))

# %% [markdown]
# ### Compiling the model
#
# [Adam optimizer](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['sparse_categorical_accuracy']
)
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                1290
# ...
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
model.fit(X_train, y_train, epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.5317 - sparse_categorical_accuracy: 0.8118
# Epoch 2/5
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.4001 - sparse_categorical_accuracy: 0.8547
# Epoch 3/5
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.3647 - sparse_categorical_accuracy: 0.8664
# Epoch 4/5
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.3480 - sparse_categorical_accuracy: 0.8722
# Epoch 5/5
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.3298 - sparse_categorical_accuracy: 0.8788

# %% [markdown]
# ### Model evaluation and prediction

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
test_loss
# Out:
# 0.36101171612739563

# %%
test_accuracy
# Out:
# 0.8678
